# %% [markdown]
# # 1. Introduction

# %% [markdown]
#  An employee in the human resources department in a company wants to predict the extent to which employees will leave in the next two years, but he decided to do a full analysis of the data and know some information such as the percentage of employees’ gender and knowing the number of employees with the same qualifications, etc. So in this analysis we will answer some questions

# %% [markdown]
# # 2. The data set definition

# %% [markdown]
# 1. Education - Education of the employee - {Bachelors,Masters,Phd}.
# 2. JoiningYear - Joining Year of the employee - {2012,2013,2014,2015,2016,2017,2018}.
# 3. City - Working location of the employee - {Bangalore,Pune,New Delhi}.
# 4. PaymentTier - Type of payments - {1(High),2(Medium),3(Lowest)}.
# 5. Age - Age of the employee - {20-45}.
# 6. Gender - Gender of the employee - {Male,Female}.
# 7. EverBenched - Whether the employee has ever been on bench-means he/she wasnt working on any project - {'Yes','No'}.
# 8. ExperienceInCurrentDomain - How much experience an employee has in current domain?
# 9. LeaveOrNot - Which employee will leave the organizaion? - {0(Not),1(Leave)}

# %% [markdown]
# # 3. Importing libraries and load the data

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\manda\Downloads\Employee.csv")

# %%
data
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
data.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1

# %%
data.tail()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 4648                          4           0
# 4649                          2           1
# 4650                          5           1
# 4651                          2           0
# 4652                          4           0

# %%
data.shape
# Out:
# (4653, 9)

# %% [markdown]
# "4653" coloumns and "9" Rows Present In Data

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4648     True
# 4649    False
# 4650    False
# 4651    False
# 4652     True
# Length: 4653, dtype: bool

# %%
data.isnull().sum()
# Out:
# Education                    0
# JoiningYear                  0
# City                         0
# PaymentTier                  0
# Age                          0
# Gender                       0
# EverBenched                  0
# ExperienceInCurrentDomain    0
# LeaveOrNot                   0
# dtype: int64

# %%
data.describe()
# Out:
#        JoiningYear  PaymentTier          Age  ExperienceInCurrentDomain  \
# count  4653.000000  4653.000000  4653.000000                4653.000000
# mean   2015.062970     2.698259    29.393295                   2.905652
# std       1.863377     0.561435     4.826087                   1.558240
# min    2012.000000     1.000000    22.000000                   0.000000
# 25%    2013.000000     3.000000    26.000000                   2.000000
# 50%    2015.000000     3.000000    28.000000                   3.000000
# 75%    2017.000000     3.000000    32.000000                   4.000000
# max    2018.000000     3.000000    41.000000                   7.000000
#
#         LeaveOrNot
# count  4653.000000
# mean      0.343864
# std       0.475047
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
data.value_counts()
# Out:
# Education  JoiningYear  City       PaymentTier  Age  Gender  EverBenched  ExperienceInCurrentDomain  LeaveOrNot
# Bachelors  2013         Bangalore  3            26   Male    No           4                          0             32
#            2016         Bangalore  3            26   Male    No           4                          0             28
#            2012         Bangalore  3            26   Male    No           4                          0             26
#            2014         Bangalore  3            25   Male    No           3                          0             24
#                                                 26   Male    No           4                          0             24
#                                                                                                                    ..
#            2013         Bangalore  3            33   Male    No           3                          0              1
# ...

# %% [markdown]
# # 4.Visulization

# %%
data.hist(bins = 10 , figsize = (8,7)  , color= "LightSeaGreen")
plt.show()

# %% [markdown]
# .This graphs explain that most of employees joined to our company at 2017
#
# .Most of employees get a good salary
#
# .Most of employees joined to our company at 25 - 29 YO
#
# .Most of employees in the company have 2 years experience
#
# .Most of employees will not leave the company

# %%
data['PaymentTier'].replace(1 , "BetterPay" , inplace = True)
data['PaymentTier'].replace(2 , "MidPay" , inplace = True)
data['PaymentTier'].replace(3 , "WorestPay" , inplace = True)
sns.catplot(data=data,kind="count",x='Education',hue="PaymentTier",palette = "pastel")

# %% [markdown]
# Bschelors are the most in employees as the biggest pie part is in Bschelors than the master and PHd

# %%
gen=data["Gender"].value_counts()
print(gen)
gen.plot.pie(subplots = True,autopct='%1.1f%%', colors = ['SlateGray', 'Pink'])
# Out:
# Male      2778
# Female    1875
# Name: Gender, dtype: int64
# array([<AxesSubplot:ylabel='Gender'>], dtype=object)

# %% [markdown]
# pie chart shows Men ratio is more than Femalr

# %%
sns.catplot(data=data,kind="count",x='Gender',hue="EverBenched", )

# %% [markdown]
# Plot shows Men are the most benched tahn Female

# %%
sns.heatmap(data.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# There is a good relation between (From the strongest to the weakest):-
#
# 1.JoiningYear & LeaveOrNot
#
# 2.PaymentTier & ExperienceInCurrentDomain
#
# 3.Age & JoiningYear
#
# 4.PaymentTier & Age

# %%
sns.catplot(y="Age", x="PaymentTier",hue="LeaveOrNot",data=data,palette="flare")

# %% [markdown]
# Plot Shows Most of midpay employee leave the company

# %%
sns.barplot(x='City',y='LeaveOrNot',data=data)
plt.show()
sns.barplot(x='Education',y='LeaveOrNot',data=data)
plt.show()

# %% [markdown]
# Most of the Employees from the City of Pune Left the Company more than the other Employees.
# Employees Who own Masters Degree left other than other employees.

# %%
sns.displot(data=data, x="ExperienceInCurrentDomain", hue="LeaveOrNot",kind="kde")

# %% [markdown]
# Employees with 2 years of experience in their domain are the most to leave.

# %%
Benched= data['EverBenched'].value_counts()
Benched.plot.pie(autopct = '%1.1f%%',shadow=True ,explode = (0.1, 0.1))
# Out:
# <AxesSubplot:ylabel='EverBenched'>

# %% [markdown]
# Pie chart shows Most of the employee are NotBenched.

# %%
Benched=data["EverBenched"].value_counts()
print(Benched)
sns.countplot(data=data,x='EverBenched',hue='LeaveOrNot',palette=['SlateGray','Red'])
# Out:
# No     4175
# Yes     478
# Name: EverBenched, dtype: int64
# <AxesSubplot:xlabel='EverBenched', ylabel='count'>

# %% [markdown]
# Most Employees who get benched leave( approximately 80%)

# %%
sns.lineplot(x=data['Gender'],y=data['LeaveOrNot'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='LeaveOrNot'>

# %% [markdown]
# A lot of females tend to leave company

# %%
sns.lineplot(x=data['JoiningYear'],y=data['LeaveOrNot'])
# Out:
# <AxesSubplot:xlabel='JoiningYear', ylabel='LeaveOrNot'>

# %% [markdown]
# Trend line show that The rate of employees leaving the company is hight in 2018 year

# %% [markdown]
# # Conclusion

# %% [markdown]
# ### Pros:

# %% [markdown]
# .Not many employees get benched.
#
# .23% of our employees have a masters degree.
#
# .Not many employees from New Delhi leave our company.

# %% [markdown]
# ### Cons:

# %% [markdown]
# .A lot of females tend to leave our company.
#
# .No strong relations between our dataset columns (not a business related problem)
#
# .Most employees that live in Pune leave (more than 50% of employees living there)
# More people at age from 22.5 to 26 leave the company in payment tier 2 than any other tier.
#
# .In 2018 most of the employees left.
#
# .Most Employees who get benched leave ( approximately 45%).
#
# .Employees with 2 years of experience in their domain are the most to leave.

# %% [markdown]
# ## Solution:

# %% [markdown]
# .Make the work enviroment more suitable for females to work in.
#
# .Supply employees from Pune more means of transportation.
#
# .Supply employees from Bnagalore more means of transportation.
#
# .Try encourage employees aged from 22 till 26 to stay by rewarding them with bonuses or ranking them up in Payment tiers.
#
# .Review what went wrong in 2018 because nearly all employees left the company. (CRITICAL PROBLEM)
#
# .Try to lower down employee benching rate by rotating more employees in projects.
#
# .Encourage employees with 2 years of experience of stay by invloving them in more projects to gain more experience and also get paid more.
